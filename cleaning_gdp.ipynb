# %%
import pandas as pd

# %%
def trimester_to_date(trimester):
    year, quarter = trimester.split('-')
    quarter=quarter[1]
    month = int(quarter) * 3
    return pd.Timestamp(year=int(year), month=month, day=1)

# %%
real_gdp =pd.read_csv('global/realgdpoecd.csv')

# %%
real_gdp
# Out:
#        STRUCTURE                                       STRUCTURE_ID  \
# 0       DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# 1       DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# 2       DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# 3       DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# 4       DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# ...          ...                                                ...
# 135871  DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# 135872  DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# 135873  DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# 135874  DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# 135875  DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
#
#                                            STRUCTURE_NAME ACTION FREQ  \
# 0       Croissance trimestrielle réelle du PIB - pays ...      I    A
# 1       Croissance trimestrielle réelle du PIB - pays ...      I    A
# 2       Croissance trimestrielle réelle du PIB - pays ...      I    A
# 3       Croissance trimestrielle réelle du PIB - pays ...      I    A
# 4       Croissance trimestrielle réelle du PIB - pays ...      I    A
# ...                                                   ...    ...  ...
# 135871  Croissance trimestrielle réelle du PIB - pays ...      I    A
# 135872  Croissance trimestrielle réelle du PIB - pays ...      I    A
# 135873  Croissance trimestrielle réelle du PIB - pays ...      I    A
# 135874  Croissance trimestrielle réelle du PIB - pays ...      I    A
# 135875  Croissance trimestrielle réelle du PIB - pays ...      I    A
#
#        Fréquence d'observation ADJUSTMENT  \
# 0                     Annuelle          Y
# 1                     Annuelle          Y
# 2                     Annuelle          Y
# 3                     Annuelle          Y
# 4                     Annuelle          Y
# ...                        ...        ...
# 135871                Annuelle          Y
# 135872                Annuelle          Y
# 135873                Annuelle          Y
# 135874                Annuelle          Y
# 135875                Annuelle          Y
#
#                                                Ajustement REF_AREA  \
# 0       Corrigé des variations saisonnières et des eff...      SVN
# 1       Corrigé des variations saisonnières et des eff...      SVN
# 2       Corrigé des variations saisonnières et des eff...      SVN
# 3       Corrigé des variations saisonnières et des eff...      SVN
# 4       Corrigé des variations saisonnières et des eff...      SVN
# ...                                                   ...      ...
# 135871  Corrigé des variations saisonnières et des eff...      SVN
# 135872  Corrigé des variations saisonnières et des eff...      SVN
# 135873  Corrigé des variations saisonnières et des eff...      SVN
# 135874  Corrigé des variations saisonnières et des eff...      SVN
# 135875  Corrigé des variations saisonnières et des eff...      SVN
#
#        Zone de référence  ... CONF_STATUS       Statut de confidentialité  \
# 0               Slovénie  ...           F  Libre (libre pour publication)
# 1               Slovénie  ...           F  Libre (libre pour publication)
# 2               Slovénie  ...           F  Libre (libre pour publication)
# 3               Slovénie  ...           F  Libre (libre pour publication)
# 4               Slovénie  ...           F  Libre (libre pour publication)
# ...                  ...  ...         ...                             ...
# 135871          Slovénie  ...           F  Libre (libre pour publication)
# 135872          Slovénie  ...           F  Libre (libre pour publication)
# 135873          Slovénie  ...           F  Libre (libre pour publication)
# 135874          Slovénie  ...           F  Libre (libre pour publication)
# 135875          Slovénie  ...           F  Libre (libre pour publication)
#
#        DECIMALS Décimales OBS_STATUS Statut d'observation UNIT_MULT  \
# 0             1       One          A         Normal value         0
# 1             1       One          A         Normal value         0
# 2             1       One          A         Normal value         0
# 3             1       One          A         Normal value         0
# 4             1       One          A         Normal value         0
# ...         ...       ...        ...                  ...       ...
# 135871        1       One          A         Normal value         0
# 135872        1       One          A         Normal value         0
# 135873        1       One          A         Normal value         0
# 135874        1       One          A         Normal value         0
# 135875        1       One          A         Normal value         0
#
#        Multiplicateur d'unité CURRENCY               Monnaie
# 0                       Units       _Z  N'est pas applicable
# 1                       Units       _Z  N'est pas applicable
# 2                       Units       _Z  N'est pas applicable
# 3                       Units       _Z  N'est pas applicable
# 4                       Units       _Z  N'est pas applicable
# ...                       ...      ...                   ...
# 135871                  Units       _Z  N'est pas applicable
# 135872                  Units       _Z  N'est pas applicable
# 135873                  Units       _Z  N'est pas applicable
# 135874                  Units       _Z  N'est pas applicable
# 135875                  Units       _Z  N'est pas applicable
#
# [135876 rows x 48 columns]

# %%
real_gdp["Multiplicateur d'unité"].unique()
# Out:
# array(['Units'], dtype=object)

# %%
real_gdp.columns
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'FREQ',
#        'Fréquence d'observation', 'ADJUSTMENT', 'Ajustement', 'REF_AREA',
#        'Zone de référence', 'SECTOR', 'Secteur institutionnel',
#        'COUNTERPART_SECTOR', 'Secteur institutionnel de contrepartie',
#        'TRANSACTION', 'Transaction', 'INSTR_ASSET',
#        'Instruments financiers et actifs non financiers', 'ACTIVITY',
#        'Activité économique', 'EXPENDITURE', 'Dépense', 'UNIT_MEASURE',
#        'Unité de mesure', 'PRICE_BASE', 'Type de prix', 'TRANSFORMATION',
#        'Transformation', 'TABLE_IDENTIFIER', 'Identifiant de tableau',
#        'TIME_PERIOD', 'Période temporelle', 'OBS_VALUE',
#        'Valeur d'observation', 'REF_YEAR_PRICE', 'Prix ​​année de référence',
#        'BASE_PER', 'Période de base', 'CONF_STATUS',
#        'Statut de confidentialité', 'DECIMALS', 'Décimales', 'OBS_STATUS',
#        'Statut d'observation', 'UNIT_MULT', 'Multiplicateur d'unité',
#        'CURRENCY', 'Monnaie'],
#       dtype='object')

# %%
#dropping unimportant columns
real_gdp.drop(columns=["REF_AREA", "OBS_STATUS"], inplace=True)

# %%
for column in real_gdp.columns:
    if (len(real_gdp[column].unique()) <= 1) and (column != "Unité de mesure"):
        real_gdp.drop(columns=[column],inplace=True)

# %%
real_gdp
# Out:
#        FREQ Fréquence d'observation Zone de référence SECTOR  \
# 0         A                Annuelle          Slovénie     S1
# 1         A                Annuelle          Slovénie     S1
# 2         A                Annuelle          Slovénie     S1
# 3         A                Annuelle          Slovénie     S1
# 4         A                Annuelle          Slovénie     S1
# ...     ...                     ...               ...    ...
# 135871    A                Annuelle          Slovénie     S1
# 135872    A                Annuelle          Slovénie     S1
# 135873    A                Annuelle          Slovénie     S1
# 135874    A                Annuelle          Slovénie     S1
# 135875    A                Annuelle          Slovénie     S1
#
#        Secteur institutionnel TRANSACTION  \
# 0             Economie totale          P6
# 1             Economie totale          P6
# 2             Economie totale          P6
# 3             Economie totale          P6
# 4             Economie totale          P6
# ...                       ...         ...
# 135871        Economie totale        B1GQ
# 135872        Economie totale        B1GQ
# 135873        Economie totale        B1GQ
# 135874        Economie totale        B1GQ
# 135875        Economie totale        B1GQ
#
#                                  Transaction ACTIVITY Activité économique  \
# 0       Exportations de biens et de services       _Z      Non applicable
# 1       Exportations de biens et de services       _Z      Non applicable
# 2       Exportations de biens et de services       _Z      Non applicable
# 3       Exportations de biens et de services       _Z      Non applicable
# 4       Exportations de biens et de services       _Z      Non applicable
# ...                                      ...      ...                 ...
# 135871                Produit intérieur brut       _Z      Non applicable
# 135872                Produit intérieur brut       _Z      Non applicable
# 135873                Produit intérieur brut       _Z      Non applicable
# 135874                Produit intérieur brut       _Z      Non applicable
# 135875                Produit intérieur brut       _Z      Non applicable
#
#        EXPENDITURE         Dépense            Unité de mesure TRANSFORMATION  \
# 0               _Z  Non-applicable  Changement en pourcentage             GY
# 1               _Z  Non-applicable  Changement en pourcentage             GY
# 2               _Z  Non-applicable  Changement en pourcentage             GY
# 3               _Z  Non-applicable  Changement en pourcentage             GY
# 4               _Z  Non-applicable  Changement en pourcentage             GY
# ...            ...             ...                        ...            ...
# 135871          _Z  Non-applicable  Changement en pourcentage             GY
# 135872          _Z  Non-applicable  Changement en pourcentage             GY
# 135873          _Z  Non-applicable  Changement en pourcentage             GY
# 135874          _Z  Non-applicable  Changement en pourcentage             GY
# 135875          _Z  Non-applicable  Changement en pourcentage             GY
#
#                       Transformation TIME_PERIOD  OBS_VALUE REF_YEAR_PRICE  \
# 0       Taux de croissance, sur 1 an        1996   2.971844            NaN
# 1       Taux de croissance, sur 1 an        1997  11.634627            NaN
# 2       Taux de croissance, sur 1 an        1998   7.821850            NaN
# 3       Taux de croissance, sur 1 an        1999   2.004500            NaN
# 4       Taux de croissance, sur 1 an        2000  12.592517            NaN
# ...                              ...         ...        ...            ...
# 135871  Taux de croissance, sur 1 an        2019   3.522680            NaN
# 135872  Taux de croissance, sur 1 an        2020  -4.240883            NaN
# 135873  Taux de croissance, sur 1 an        2021   8.228498            NaN
# 135874  Taux de croissance, sur 1 an        2022   2.460784            NaN
# 135875  Taux de croissance, sur 1 an        2023   1.586899            NaN
#
#        Statut d'observation
# 0              Normal value
# 1              Normal value
# 2              Normal value
# 3              Normal value
# 4              Normal value
# ...                     ...
# 135871         Normal value
# 135872         Normal value
# 135873         Normal value
# 135874         Normal value
# 135875         Normal value
#
# [135876 rows x 18 columns]

# %%
#leave only the trimesters values
real_gdp = real_gdp[real_gdp["FREQ"] == "Q"]
real_gdp.TIME_PERIOD = real_gdp.TIME_PERIOD.apply(lambda x: trimester_to_date(x))
# Out:
# C:\Users\vadim\AppData\Local\Temp\ipykernel_80\1248580636.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_gdp.TIME_PERIOD = real_gdp.TIME_PERIOD.apply(lambda x: trimester_to_date(x))

# %%
real_gdp
# Out:
#        FREQ Fréquence d'observation Zone de référence SECTOR  \
# 28        Q           Trimestrielle       OCDE Europe    S13
# 29        Q           Trimestrielle       OCDE Europe    S13
# 30        Q           Trimestrielle       OCDE Europe    S13
# 31        Q           Trimestrielle       OCDE Europe    S13
# 32        Q           Trimestrielle       OCDE Europe    S13
# ...     ...                     ...               ...    ...
# 135843    Q           Trimestrielle           Pologne     S1
# 135844    Q           Trimestrielle           Pologne     S1
# 135845    Q           Trimestrielle           Pologne     S1
# 135846    Q           Trimestrielle           Pologne     S1
# 135847    Q           Trimestrielle           Pologne     S1
#
#            Secteur institutionnel TRANSACTION  \
# 28      Administrations publiques          P3
# 29      Administrations publiques          P3
# 30      Administrations publiques          P3
# 31      Administrations publiques          P3
# 32      Administrations publiques          P3
# ...                           ...         ...
# 135843            Economie totale        P51G
# 135844            Economie totale        P51G
# 135845            Economie totale        P51G
# 135846            Economie totale        P51G
# 135847            Economie totale        P51G
#
#                             Transaction ACTIVITY  \
# 28       Dépense de consommation finale       _Z
# 29       Dépense de consommation finale       _Z
# 30       Dépense de consommation finale       _Z
# 31       Dépense de consommation finale       _Z
# 32       Dépense de consommation finale       _Z
# ...                                 ...      ...
# 135843  Formation brute de capital fixe       _T
# 135844  Formation brute de capital fixe       _T
# 135845  Formation brute de capital fixe       _T
# 135846  Formation brute de capital fixe       _T
# 135847  Formation brute de capital fixe       _T
#
#                  Activité économique EXPENDITURE         Dépense  \
# 28                    Non applicable          _T           Total
# 29                    Non applicable          _T           Total
# 30                    Non applicable          _T           Total
# 31                    Non applicable          _T           Total
# 32                    Non applicable          _T           Total
# ...                              ...         ...             ...
# 135843  Total - Toutes les activités          _Z  Non-applicable
# 135844  Total - Toutes les activités          _Z  Non-applicable
# 135845  Total - Toutes les activités          _Z  Non-applicable
# 135846  Total - Toutes les activités          _Z  Non-applicable
# 135847  Total - Toutes les activités          _Z  Non-applicable
#
#                   Unité de mesure TRANSFORMATION  \
# 28      Changement en pourcentage             G1
# 29      Changement en pourcentage             G1
# 30      Changement en pourcentage             G1
# 31      Changement en pourcentage             G1
# 32      Changement en pourcentage             G1
# ...                           ...            ...
# 135843  Changement en pourcentage             GY
# 135844  Changement en pourcentage             GY
# 135845  Changement en pourcentage             GY
# 135846  Changement en pourcentage             GY
# 135847  Changement en pourcentage             GY
#
#                                  Transformation TIME_PERIOD  OBS_VALUE  \
# 28      Taux de croissance, période sur période  1961-06-01   0.644198
# 29      Taux de croissance, période sur période  1961-09-01   1.725270
# 30      Taux de croissance, période sur période  1961-12-01   1.222290
# 31      Taux de croissance, période sur période  1962-03-01   1.613121
# 32      Taux de croissance, période sur période  1962-06-01   1.618299
# ...                                         ...         ...        ...
# 135843             Taux de croissance, sur 1 an  2022-12-01   4.657891
# 135844             Taux de croissance, sur 1 an  2023-03-01   5.955150
# 135845             Taux de croissance, sur 1 an  2023-06-01   7.388818
# 135846             Taux de croissance, sur 1 an  2023-09-01   8.031019
# 135847             Taux de croissance, sur 1 an  2023-12-01   9.711023
#
#        REF_YEAR_PRICE Statut d'observation
# 28                NaN         Normal value
# 29                NaN         Normal value
# 30                NaN         Normal value
# 31                NaN         Normal value
# 32                NaN         Normal value
# ...               ...                  ...
# 135843            NaN         Normal value
# 135844            NaN         Normal value
# 135845            NaN         Normal value
# 135846            NaN         Normal value
# 135847            NaN         Normal value
#
# [109672 rows x 18 columns]

# %%
real_gdp.drop(columns=["FREQ", "Fréquence d'observation", "TRANSACTION", "SECTOR", "REF_YEAR_PRICE",
                        "ACTIVITY", "EXPENDITURE", "TRANSFORMATION"], inplace=True)
# Out:
# C:\Users\vadim\AppData\Local\Temp\ipykernel_80\1889910554.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_gdp.drop(columns=["FREQ", "Fréquence d'observation", "TRANSACTION", "SECTOR", "REF_YEAR_PRICE",

# %%
real_gdp
# Out:
#        Zone de référence     Secteur institutionnel  \
# 28           OCDE Europe  Administrations publiques
# 29           OCDE Europe  Administrations publiques
# 30           OCDE Europe  Administrations publiques
# 31           OCDE Europe  Administrations publiques
# 32           OCDE Europe  Administrations publiques
# ...                  ...                        ...
# 135843           Pologne            Economie totale
# 135844           Pologne            Economie totale
# 135845           Pologne            Economie totale
# 135846           Pologne            Economie totale
# 135847           Pologne            Economie totale
#
#                             Transaction           Activité économique  \
# 28       Dépense de consommation finale                Non applicable
# 29       Dépense de consommation finale                Non applicable
# 30       Dépense de consommation finale                Non applicable
# 31       Dépense de consommation finale                Non applicable
# 32       Dépense de consommation finale                Non applicable
# ...                                 ...                           ...
# 135843  Formation brute de capital fixe  Total - Toutes les activités
# 135844  Formation brute de capital fixe  Total - Toutes les activités
# 135845  Formation brute de capital fixe  Total - Toutes les activités
# 135846  Formation brute de capital fixe  Total - Toutes les activités
# 135847  Formation brute de capital fixe  Total - Toutes les activités
#
#                Dépense            Unité de mesure  \
# 28               Total  Changement en pourcentage
# 29               Total  Changement en pourcentage
# 30               Total  Changement en pourcentage
# 31               Total  Changement en pourcentage
# 32               Total  Changement en pourcentage
# ...                ...                        ...
# 135843  Non-applicable  Changement en pourcentage
# 135844  Non-applicable  Changement en pourcentage
# 135845  Non-applicable  Changement en pourcentage
# 135846  Non-applicable  Changement en pourcentage
# 135847  Non-applicable  Changement en pourcentage
#
#                                  Transformation TIME_PERIOD  OBS_VALUE  \
# 28      Taux de croissance, période sur période  1961-06-01   0.644198
# 29      Taux de croissance, période sur période  1961-09-01   1.725270
# 30      Taux de croissance, période sur période  1961-12-01   1.222290
# 31      Taux de croissance, période sur période  1962-03-01   1.613121
# 32      Taux de croissance, période sur période  1962-06-01   1.618299
# ...                                         ...         ...        ...
# 135843             Taux de croissance, sur 1 an  2022-12-01   4.657891
# 135844             Taux de croissance, sur 1 an  2023-03-01   5.955150
# 135845             Taux de croissance, sur 1 an  2023-06-01   7.388818
# 135846             Taux de croissance, sur 1 an  2023-09-01   8.031019
# 135847             Taux de croissance, sur 1 an  2023-12-01   9.711023
#
#        Statut d'observation
# 28             Normal value
# 29             Normal value
# 30             Normal value
# 31             Normal value
# 32             Normal value
# ...                     ...
# 135843         Normal value
# 135844         Normal value
# 135845         Normal value
# 135846         Normal value
# 135847         Normal value
#
# [109672 rows x 10 columns]

# %%
real_gdp["Dépense"]
real_gdp.drop(columns=["Dépense"], inplace=True)
# Out:
# C:\Users\vadim\AppData\Local\Temp\ipykernel_80\864960113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_gdp.drop(columns=["Dépense"], inplace=True)

# %%
real_gdp["Activité économique"].unique()
# Out:
# array(['Non applicable', 'Total - Toutes les activités'], dtype=object)

# %%
real_gdp["Statut d'observation"].unique()
real_gdp.drop(columns=["Statut d'observation"], inplace=True)
# Out:
# C:\Users\vadim\AppData\Local\Temp\ipykernel_80\1136847575.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_gdp.drop(columns=["Statut d'observation"], inplace=True)

# %%
real_gdp = real_gdp[real_gdp["Secteur institutionnel"] == "Economie totale"]
real_gdp = real_gdp[real_gdp["Transaction"] == "Produit intérieur brut"]
real_gdp = real_gdp[real_gdp["Transformation"] == "Taux de croissance, sur 1 an"]

real_gdp
# Out:
#        Zone de référence Secteur institutionnel             Transaction  \
# 2424             Norvège        Economie totale  Produit intérieur brut
# 2425             Norvège        Economie totale  Produit intérieur brut
# 2426             Norvège        Economie totale  Produit intérieur brut
# 2427             Norvège        Economie totale  Produit intérieur brut
# 2428             Norvège        Economie totale  Produit intérieur brut
# ...                  ...                    ...                     ...
# 135319          Belgique        Economie totale  Produit intérieur brut
# 135320          Belgique        Economie totale  Produit intérieur brut
# 135321          Belgique        Economie totale  Produit intérieur brut
# 135322          Belgique        Economie totale  Produit intérieur brut
# 135323          Belgique        Economie totale  Produit intérieur brut
#
#        Activité économique            Unité de mesure  \
# 2424        Non applicable  Changement en pourcentage
# 2425        Non applicable  Changement en pourcentage
# 2426        Non applicable  Changement en pourcentage
# 2427        Non applicable  Changement en pourcentage
# 2428        Non applicable  Changement en pourcentage
# ...                    ...                        ...
# 135319      Non applicable  Changement en pourcentage
# 135320      Non applicable  Changement en pourcentage
# 135321      Non applicable  Changement en pourcentage
# 135322      Non applicable  Changement en pourcentage
# 135323      Non applicable  Changement en pourcentage
#
#                       Transformation TIME_PERIOD  OBS_VALUE
# 2424    Taux de croissance, sur 1 an  1961-03-01   5.869164
# 2425    Taux de croissance, sur 1 an  1961-06-01   6.768961
# 2426    Taux de croissance, sur 1 an  1961-09-01   6.716544
# 2427    Taux de croissance, sur 1 an  1961-12-01   5.746506
# 2428    Taux de croissance, sur 1 an  1962-03-01   3.916006
# ...                              ...         ...        ...
# 135319  Taux de croissance, sur 1 an  2022-12-01   1.375801
# 135320  Taux de croissance, sur 1 an  2023-03-01   1.675528
# 135321  Taux de croissance, sur 1 an  2023-06-01   1.307926
# 135322  Taux de croissance, sur 1 an  2023-09-01   1.376709
# 135323  Taux de croissance, sur 1 an  2023-12-01   1.484547
#
# [8737 rows x 8 columns]

# %%
real_gdp.to_csv("global/dataglobal/clean_realgdp.csv")

# %% [markdown]
# ## real gdp20

# %%
real_gdp20 =pd.read_csv('global/realgdpg20.csv')

# %%
real_gdp20
# Out:
#       STRUCTURE                                       STRUCTURE_ID  \
# 0      DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# 1      DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# 2      DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# 3      DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# 4      DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# ...         ...                                                ...
# 73375  DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# 73376  DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# 73377  DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# 73378  DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
# 73379  DATAFLOW  OECD.SDD.NAD:DSD_NAMAIN1@DF_QNA_EXPENDITURE_GR...
#
#                                           STRUCTURE_NAME ACTION FREQ  \
# 0      Croissance trimestrielle réelle du PIB - pays ...      I    Q
# 1      Croissance trimestrielle réelle du PIB - pays ...      I    Q
# 2      Croissance trimestrielle réelle du PIB - pays ...      I    Q
# 3      Croissance trimestrielle réelle du PIB - pays ...      I    Q
# 4      Croissance trimestrielle réelle du PIB - pays ...      I    Q
# ...                                                  ...    ...  ...
# 73375  Croissance trimestrielle réelle du PIB - pays ...      I    A
# 73376  Croissance trimestrielle réelle du PIB - pays ...      I    A
# 73377  Croissance trimestrielle réelle du PIB - pays ...      I    A
# 73378  Croissance trimestrielle réelle du PIB - pays ...      I    A
# 73379  Croissance trimestrielle réelle du PIB - pays ...      I    A
#
#       Fréquence d'observation ADJUSTMENT  \
# 0               Trimestrielle          Y
# 1               Trimestrielle          Y
# 2               Trimestrielle          Y
# 3               Trimestrielle          Y
# 4               Trimestrielle          Y
# ...                       ...        ...
# 73375                Annuelle          Y
# 73376                Annuelle          Y
# 73377                Annuelle          Y
# 73378                Annuelle          Y
# 73379                Annuelle          Y
#
#                                               Ajustement REF_AREA  \
# 0      Corrigé des variations saisonnières et des eff...    OECDE
# 1      Corrigé des variations saisonnières et des eff...    OECDE
# 2      Corrigé des variations saisonnières et des eff...    OECDE
# 3      Corrigé des variations saisonnières et des eff...    OECDE
# 4      Corrigé des variations saisonnières et des eff...    OECDE
# ...                                                  ...      ...
# 73375  Corrigé des variations saisonnières et des eff...      SAU
# 73376  Corrigé des variations saisonnières et des eff...      SAU
# 73377  Corrigé des variations saisonnières et des eff...      SAU
# 73378  Corrigé des variations saisonnières et des eff...      SAU
# 73379  Corrigé des variations saisonnières et des eff...      SAU
#
#       Zone de référence  ... CONF_STATUS       Statut de confidentialité  \
# 0           OCDE Europe  ...           F  Libre (libre pour publication)
# 1           OCDE Europe  ...           F  Libre (libre pour publication)
# 2           OCDE Europe  ...           F  Libre (libre pour publication)
# 3           OCDE Europe  ...           F  Libre (libre pour publication)
# 4           OCDE Europe  ...           F  Libre (libre pour publication)
# ...                 ...  ...         ...                             ...
# 73375   Arabie saoudite  ...           F  Libre (libre pour publication)
# 73376   Arabie saoudite  ...           F  Libre (libre pour publication)
# 73377   Arabie saoudite  ...           F  Libre (libre pour publication)
# 73378   Arabie saoudite  ...           F  Libre (libre pour publication)
# 73379   Arabie saoudite  ...           F  Libre (libre pour publication)
#
#       DECIMALS Décimales OBS_STATUS Statut d'observation UNIT_MULT  \
# 0            1       One          A         Normal value         0
# 1            1       One          A         Normal value         0
# 2            1       One          A         Normal value         0
# 3            1       One          A         Normal value         0
# 4            1       One          A         Normal value         0
# ...        ...       ...        ...                  ...       ...
# 73375        1       One          A         Normal value         0
# 73376        1       One          A         Normal value         0
# 73377        1       One          A         Normal value         0
# 73378        1       One          A         Normal value         0
# 73379        1       One          A         Normal value         0
#
#       Multiplicateur d'unité CURRENCY               Monnaie
# 0                      Units       _Z  N'est pas applicable
# 1                      Units       _Z  N'est pas applicable
# 2                      Units       _Z  N'est pas applicable
# 3                      Units       _Z  N'est pas applicable
# 4                      Units       _Z  N'est pas applicable
# ...                      ...      ...                   ...
# 73375                  Units       _Z  N'est pas applicable
# 73376                  Units       _Z  N'est pas applicable
# 73377                  Units       _Z  N'est pas applicable
# 73378                  Units       _Z  N'est pas applicable
# 73379                  Units       _Z  N'est pas applicable
#
# [73380 rows x 48 columns]

# %%
real_gdp20["Monnaie"].unique()
# Out:
# array(["N'est pas applicable"], dtype=object)

# %%
real_gdp20.columns
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'FREQ',
#        'Fréquence d'observation', 'ADJUSTMENT', 'Ajustement', 'REF_AREA',
#        'Zone de référence', 'SECTOR', 'Secteur institutionnel',
#        'COUNTERPART_SECTOR', 'Secteur institutionnel de contrepartie',
#        'TRANSACTION', 'Transaction', 'INSTR_ASSET',
#        'Instruments financiers et actifs non financiers', 'ACTIVITY',
#        'Activité économique', 'EXPENDITURE', 'Dépense', 'UNIT_MEASURE',
#        'Unité de mesure', 'PRICE_BASE', 'Type de prix', 'TRANSFORMATION',
#        'Transformation', 'TABLE_IDENTIFIER', 'Identifiant de tableau',
#        'TIME_PERIOD', 'Période temporelle', 'OBS_VALUE',
#        'Valeur d'observation', 'REF_YEAR_PRICE', 'Prix ​​année de référence',
#        'BASE_PER', 'Période de base', 'CONF_STATUS',
#        'Statut de confidentialité', 'DECIMALS', 'Décimales', 'OBS_STATUS',
#        'Statut d'observation', 'UNIT_MULT', 'Multiplicateur d'unité',
#        'CURRENCY', 'Monnaie'],
#       dtype='object')

# %%
for column in real_gdp20.columns:
    if (len(real_gdp20[column].unique()) <= 1) and (column != "Unité de mesure"):
        real_gdp20.drop(columns=[column],inplace=True)
        
real_gdp20.drop(columns=[ "REF_AREA", "OBS_STATUS", "Statut d'observation", "Dépense", "Fréquence d'observation", "TRANSACTION", "SECTOR", "REF_YEAR_PRICE",
                        "ACTIVITY", "EXPENDITURE", "TRANSFORMATION"], inplace=True)

# %%
real_gdp20
# Out:
#       FREQ Zone de référence     Secteur institutionnel  \
# 0        Q       OCDE Europe  Administrations publiques
# 1        Q       OCDE Europe  Administrations publiques
# 2        Q       OCDE Europe  Administrations publiques
# 3        Q       OCDE Europe  Administrations publiques
# 4        Q       OCDE Europe  Administrations publiques
# ...    ...               ...                        ...
# 73375    A   Arabie saoudite            Economie totale
# 73376    A   Arabie saoudite            Economie totale
# 73377    A   Arabie saoudite            Economie totale
# 73378    A   Arabie saoudite            Economie totale
# 73379    A   Arabie saoudite            Economie totale
#
#                                 Transaction Activité économique  \
# 0            Dépense de consommation finale      Non applicable
# 1            Dépense de consommation finale      Non applicable
# 2            Dépense de consommation finale      Non applicable
# 3            Dépense de consommation finale      Non applicable
# 4            Dépense de consommation finale      Non applicable
# ...                                     ...                 ...
# 73375  Importations de biens et de services      Non applicable
# 73376  Importations de biens et de services      Non applicable
# 73377  Importations de biens et de services      Non applicable
# 73378  Importations de biens et de services      Non applicable
# 73379  Importations de biens et de services      Non applicable
#
#                  Unité de mesure                           Transformation  \
# 0      Changement en pourcentage  Taux de croissance, période sur période
# 1      Changement en pourcentage  Taux de croissance, période sur période
# 2      Changement en pourcentage  Taux de croissance, période sur période
# 3      Changement en pourcentage  Taux de croissance, période sur période
# 4      Changement en pourcentage  Taux de croissance, période sur période
# ...                          ...                                      ...
# 73375  Changement en pourcentage  Taux de croissance, période sur période
# 73376  Changement en pourcentage  Taux de croissance, période sur période
# 73377  Changement en pourcentage  Taux de croissance, période sur période
# 73378  Changement en pourcentage  Taux de croissance, période sur période
# 73379  Changement en pourcentage  Taux de croissance, période sur période
#
#       TIME_PERIOD  OBS_VALUE
# 0         1961-Q2   0.644198
# 1         1961-Q3   1.725270
# 2         1961-Q4   1.222290
# 3         1962-Q1   1.613121
# 4         1962-Q2   1.618299
# ...           ...        ...
# 73375        2019   9.473359
# 73376        2020 -19.897070
# 73377        2021   8.341103
# 73378        2022  12.426452
# 73379        2023   9.854934
#
# [73380 rows x 9 columns]

# %%
real_gdp20["Zone de référence"].unique()
# Out:
# array(['OCDE Europe', 'Brésil', 'Zone euro (20 pays)', 'Russie', 'OCDE',
#        'Argentine', 'Mexique', 'Australie', 'Inde', 'G7', 'Türkiye',
#        'Allemagne', 'Corée',
#        'Union européenne (27 pays à partir du 01/02/2020)', 'France',
#        'Afrique du Sud', 'Indonésie', 'Italie', 'ALENA', 'États-Unis',
#        'Arabie saoudite', 'Japon', 'Royaume-Uni', 'G20', 'Canada',
#        'Chine (République populaire de)'], dtype=object)

# %%
real_gdp20["TIME_PERIOD"].unique()
# Out:
# array(['1961-Q2', '1961-Q3', '1961-Q4', '1962-Q1', '1962-Q2', '1962-Q3',
#        '1962-Q4', '1963-Q1', '1963-Q2', '1963-Q3', '1963-Q4', '1964-Q1',
#        '1964-Q2', '1964-Q3', '1964-Q4', '1965-Q1', '1965-Q2', '1965-Q3',
#        '1965-Q4', '1966-Q1', '1966-Q2', '1966-Q3', '1966-Q4', '1967-Q1',
#        '1967-Q2', '1967-Q3', '1967-Q4', '1968-Q1', '1968-Q2', '1968-Q3',
#        '1968-Q4', '1969-Q1', '1969-Q2', '1969-Q3', '1969-Q4', '1970-Q1',
#        '1970-Q2', '1970-Q3', '1970-Q4', '1971-Q1', '1971-Q2', '1971-Q3',
#        '1971-Q4', '1972-Q1', '1972-Q2', '1972-Q3', '1972-Q4', '1973-Q1',
#        '1973-Q2', '1973-Q3', '1973-Q4', '1974-Q1', '1974-Q2', '1974-Q3',
#        '1974-Q4', '1975-Q1', '1975-Q2', '1975-Q3', '1975-Q4', '1976-Q1',
#        '1976-Q2', '1976-Q3', '1976-Q4', '1977-Q1', '1977-Q2', '1977-Q3',
#        '1977-Q4', '1978-Q1', '1978-Q2', '1978-Q3', '1978-Q4', '1979-Q1',
#        '1979-Q2', '1979-Q3', '1979-Q4', '1980-Q1', '1980-Q2', '1980-Q3',
#        '1980-Q4', '1981-Q1', '1981-Q2', '1981-Q3', '1981-Q4', '1982-Q1',
#        '1982-Q2', '1982-Q3', '1982-Q4', '1983-Q1', '1983-Q2', '1983-Q3',
#        '1983-Q4', '1984-Q1', '1984-Q2', '1984-Q3', '1984-Q4', '1985-Q1',
#        '1985-Q2', '1985-Q3', '1985-Q4', '1986-Q1', '1986-Q2', '1986-Q3',
#        '1986-Q4', '1987-Q1', '1987-Q2', '1987-Q3', '1987-Q4', '1988-Q1',
#        '1988-Q2', '1988-Q3', '1988-Q4', '1989-Q1', '1989-Q2', '1989-Q3',
#        '1989-Q4', '1990-Q1', '1990-Q2', '1990-Q3', '1990-Q4', '1991-Q1',
#        '1991-Q2', '1991-Q3', '1991-Q4', '1992-Q1', '1992-Q2', '1992-Q3',
#        '1992-Q4', '1993-Q1', '1993-Q2', '1993-Q3', '1993-Q4', '1994-Q1',
#        '1994-Q2', '1994-Q3', '1994-Q4', '1995-Q1', '1995-Q2', '1995-Q3',
#        '1995-Q4', '1996-Q1', '1996-Q2', '1996-Q3', '1996-Q4', '1997-Q1',
#        '1997-Q2', '1997-Q3', '1997-Q4', '1998-Q1', '1998-Q2', '1998-Q3',
#        '1998-Q4', '1999-Q1', '1999-Q2', '1999-Q3', '1999-Q4', '2000-Q1',
#        '2000-Q2', '2000-Q3', '2000-Q4', '2001-Q1', '2001-Q2', '2001-Q3',
#        '2001-Q4', '2002-Q1', '2002-Q2', '2002-Q3', '2002-Q4', '2003-Q1',
#        '2003-Q2', '2003-Q3', '2003-Q4', '2004-Q1', '2004-Q2', '2004-Q3',
#        '2004-Q4', '2005-Q1', '2005-Q2', '2005-Q3', '2005-Q4', '2006-Q1',
#        '2006-Q2', '2006-Q3', '2006-Q4', '2007-Q1', '2007-Q2', '2007-Q3',
#        '2007-Q4', '2008-Q1', '2008-Q2', '2008-Q3', '2008-Q4', '2009-Q1',
#        '2009-Q2', '2009-Q3', '2009-Q4', '2010-Q1', '2010-Q2', '2010-Q3',
#        '2010-Q4', '2011-Q1', '2011-Q2', '2011-Q3', '2011-Q4', '2012-Q1',
#        '2012-Q2', '2012-Q3', '2012-Q4', '2013-Q1', '2013-Q2', '2013-Q3',
#        '2013-Q4', '2014-Q1', '2014-Q2', '2014-Q3', '2014-Q4', '2015-Q1',
#        '2015-Q2', '2015-Q3', '2015-Q4', '2016-Q1', '2016-Q2', '2016-Q3',
#        '2016-Q4', '2017-Q1', '2017-Q2', '2017-Q3', '2017-Q4', '2018-Q1',
#        '2018-Q2', '2018-Q3', '2018-Q4', '2019-Q1', '2019-Q2', '2019-Q3',
#        '2019-Q4', '2020-Q1', '2020-Q2', '2020-Q3', '2020-Q4', '2021-Q1',
#        '2021-Q2', '2021-Q3', '2021-Q4', '2022-Q1', '2022-Q2', '2022-Q3',
#        '2022-Q4', '2023-Q1', '2023-Q2', '2023-Q3', '2023-Q4', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021', '2022', '2023', '1961', '1962', '1963', '1964', '1965',
#        '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1960-Q2',
#        '1960-Q3', '1960-Q4', '1961-Q1', '1948', '1949', '1950', '1951',
#        '1952', '1953', '1954', '1955', '1956', '1957', '1958', '1959',
#        '1960', '1955-Q2', '1955-Q3', '1955-Q4', '1956-Q1', '1956-Q2',
#        '1956-Q3', '1956-Q4', '1957-Q1', '1957-Q2', '1957-Q3', '1957-Q4',
#        '1958-Q1', '1958-Q2', '1958-Q3', '1958-Q4', '1959-Q1', '1959-Q2',
#        '1959-Q3', '1959-Q4', '1960-Q1', '1947-Q2', '1947-Q3', '1947-Q4',
#        '1948-Q1', '1948-Q2', '1948-Q3', '1948-Q4', '1949-Q1', '1949-Q2',
#        '1949-Q3', '1949-Q4', '1950-Q1', '1950-Q2', '1950-Q3', '1950-Q4',
#        '1951-Q1', '1951-Q2', '1951-Q3', '1951-Q4', '1952-Q1', '1952-Q2',
#        '1952-Q3', '1952-Q4', '1953-Q1', '1953-Q2', '1953-Q3', '1953-Q4',
#        '1954-Q1', '1954-Q2', '1954-Q3', '1954-Q4', '1955-Q1'],
#       dtype=object)

# %%
#leave only the trimesters values
real_gdp20 = real_gdp20[real_gdp20["FREQ"] == "Q"]
real_gdp20.TIME_PERIOD = real_gdp20.TIME_PERIOD.apply(lambda x: trimester_to_date(x))
# Out:
# C:\Users\vadim\AppData\Local\Temp\ipykernel_80\4237816090.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_gdp20.TIME_PERIOD = real_gdp20.TIME_PERIOD.apply(lambda x: trimester_to_date(x))

# %%
real_gdp20
# Out:
#       FREQ Zone de référence     Secteur institutionnel  \
# 0        Q       OCDE Europe  Administrations publiques
# 1        Q       OCDE Europe  Administrations publiques
# 2        Q       OCDE Europe  Administrations publiques
# 3        Q       OCDE Europe  Administrations publiques
# 4        Q       OCDE Europe  Administrations publiques
# ...    ...               ...                        ...
# 73362    Q   Arabie saoudite            Economie totale
# 73363    Q   Arabie saoudite            Economie totale
# 73364    Q   Arabie saoudite            Economie totale
# 73365    Q   Arabie saoudite            Economie totale
# 73366    Q   Arabie saoudite            Economie totale
#
#                                 Transaction Activité économique  \
# 0            Dépense de consommation finale      Non applicable
# 1            Dépense de consommation finale      Non applicable
# 2            Dépense de consommation finale      Non applicable
# 3            Dépense de consommation finale      Non applicable
# 4            Dépense de consommation finale      Non applicable
# ...                                     ...                 ...
# 73362  Importations de biens et de services      Non applicable
# 73363  Importations de biens et de services      Non applicable
# 73364  Importations de biens et de services      Non applicable
# 73365  Importations de biens et de services      Non applicable
# 73366  Importations de biens et de services      Non applicable
#
#                  Unité de mesure                           Transformation  \
# 0      Changement en pourcentage  Taux de croissance, période sur période
# 1      Changement en pourcentage  Taux de croissance, période sur période
# 2      Changement en pourcentage  Taux de croissance, période sur période
# 3      Changement en pourcentage  Taux de croissance, période sur période
# 4      Changement en pourcentage  Taux de croissance, période sur période
# ...                          ...                                      ...
# 73362  Changement en pourcentage             Taux de croissance, sur 1 an
# 73363  Changement en pourcentage             Taux de croissance, sur 1 an
# 73364  Changement en pourcentage             Taux de croissance, sur 1 an
# 73365  Changement en pourcentage             Taux de croissance, sur 1 an
# 73366  Changement en pourcentage             Taux de croissance, sur 1 an
#
#       TIME_PERIOD  OBS_VALUE
# 0      1961-06-01   0.644198
# 1      1961-09-01   1.725270
# 2      1961-12-01   1.222290
# 3      1962-03-01   1.613121
# 4      1962-06-01   1.618299
# ...           ...        ...
# 73362  2022-12-01   3.605642
# 73363  2023-03-01  17.915152
# 73364  2023-06-01   4.430807
# 73365  2023-09-01  11.683939
# 73366  2023-12-01   5.875272
#
# [59214 rows x 9 columns]

# %%
real_gdp20.drop(columns=[ "FREQ"], inplace=True)
# Out:
# C:\Users\vadim\AppData\Local\Temp\ipykernel_80\2823076585.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_gdp20.drop(columns=[ "FREQ"], inplace=True)

# %%
real_gdp20["Zone de référence"]
# Out:
# 0            OCDE Europe
# 1            OCDE Europe
# 2            OCDE Europe
# 3            OCDE Europe
# 4            OCDE Europe
#               ...
# 73362    Arabie saoudite
# 73363    Arabie saoudite
# 73364    Arabie saoudite
# 73365    Arabie saoudite
# 73366    Arabie saoudite
# Name: Zone de référence, Length: 59214, dtype: object

# %%
real_gdp20 = real_gdp20[real_gdp20["Secteur institutionnel"] == "Economie totale"]
real_gdp20 = real_gdp20[real_gdp20["Transaction"] == "Produit intérieur brut"]
real_gdp20 = real_gdp20[real_gdp20["Transformation"] == "Taux de croissance, sur 1 an"]

real_gdp20
# Out:
#       Zone de référence Secteur institutionnel             Transaction  \
# 1177        OCDE Europe        Economie totale  Produit intérieur brut
# 1178        OCDE Europe        Economie totale  Produit intérieur brut
# 1179        OCDE Europe        Economie totale  Produit intérieur brut
# 1180        OCDE Europe        Economie totale  Produit intérieur brut
# 1181        OCDE Europe        Economie totale  Produit intérieur brut
# ...                 ...                    ...                     ...
# 69540   Arabie saoudite        Economie totale  Produit intérieur brut
# 69541   Arabie saoudite        Economie totale  Produit intérieur brut
# 69542   Arabie saoudite        Economie totale  Produit intérieur brut
# 69543   Arabie saoudite        Economie totale  Produit intérieur brut
# 69544   Arabie saoudite        Economie totale  Produit intérieur brut
#
#       Activité économique            Unité de mesure  \
# 1177       Non applicable  Changement en pourcentage
# 1178       Non applicable  Changement en pourcentage
# 1179       Non applicable  Changement en pourcentage
# 1180       Non applicable  Changement en pourcentage
# 1181       Non applicable  Changement en pourcentage
# ...                   ...                        ...
# 69540      Non applicable  Changement en pourcentage
# 69541      Non applicable  Changement en pourcentage
# 69542      Non applicable  Changement en pourcentage
# 69543      Non applicable  Changement en pourcentage
# 69544      Non applicable  Changement en pourcentage
#
#                      Transformation TIME_PERIOD  OBS_VALUE
# 1177   Taux de croissance, sur 1 an  1962-03-01   4.632182
# 1178   Taux de croissance, sur 1 an  1962-06-01   4.970522
# 1179   Taux de croissance, sur 1 an  1962-09-01   5.205130
# 1180   Taux de croissance, sur 1 an  1962-12-01   4.674258
# 1181   Taux de croissance, sur 1 an  1963-03-01   2.626482
# ...                             ...         ...        ...
# 69540  Taux de croissance, sur 1 an  2022-12-01   6.272797
# 69541  Taux de croissance, sur 1 an  2023-03-01   2.436058
# 69542  Taux de croissance, sur 1 an  2023-06-01   1.225267
# 69543  Taux de croissance, sur 1 an  2023-09-01  -2.272207
# 69544  Taux de croissance, sur 1 an  2023-12-01  -4.292435
#
# [4957 rows x 8 columns]

# %%
real_gdp20.to_csv("global/dataglobal/clean_realgdpg20.csv")
